# %%
# Dependencies
import pandas as pd
import json
import numpy
import requests


fire_csv_path = "California_Fire_Incidents.csv"

fire_df = pd.read_csv(fire_csv_path)

fire = fire_df.drop(columns=["Active", "AirTankers", "CanonicalUrl", "AdminUnit", "ConditionStatement", "ControlStatement", "Status", "StructuresDamaged", "StructuresDestroyed",
                   "StructuresEvacuated", "StructuresThreatened", "WaterTenders", "CrewsInvolved", "Dozers", "Engines", "Fatalities", "PersonnelInvolved", "SearchDescription",
                   "SearchKeywords", "Helicopters", "Extinguished", "Featured", "Injuries", "Name", "FuelType"])

# %%
fire.count()
# Out:
# AcresBurned         1633
# ArchiveYear         1636
# CalFireIncident     1636
# Counties            1636
# CountyIds           1636
# Final               1636
# Latitude            1636
# Location            1636
# Longitude           1636
# MajorIncident       1636
# PercentContained    1633
# Public              1636
# Started             1636
# UniqueId            1636
# Updated             1636
# dtype: int64

# %%
fire.dropna()
# Out:
#       AcresBurned  ArchiveYear  CalFireIncident     Counties CountyIds  Final  \
# 0        257314.0         2013             True     Tuolumne        55   True
# 1         30274.0         2013             True  Los Angeles        19   True
# 2         27531.0         2013             True    Riverside        33   True
# 3         27440.0         2013            False       Placer        31   True
# 4         24251.0         2013             True      Ventura        56   True
# ...           ...          ...              ...          ...       ...    ...
# 1628         10.0         2019             True        Butte         4   True
# 1629         10.0         2019             True     Siskiyou        47   True
# 1630         10.0         2019             True        Butte         4   True
# 1631          9.0         2019             True    Riverside        33   True
# 1632          2.0         2019             True       Nevada        29   True
#
# ...

# %%
fire
# Out:
#       AcresBurned  ArchiveYear  CalFireIncident     Counties CountyIds  Final  \
# 0        257314.0         2013             True     Tuolumne        55   True
# 1         30274.0         2013             True  Los Angeles        19   True
# 2         27531.0         2013             True    Riverside        33   True
# 3         27440.0         2013            False       Placer        31   True
# 4         24251.0         2013             True      Ventura        56   True
# ...           ...          ...              ...          ...       ...    ...
# 1631          9.0         2019             True    Riverside        33   True
# 1632          2.0         2019             True       Nevada        29   True
# 1633          NaN         2019            False         Yolo        57   True
# 1634          NaN         2019            False    San Diego        37   True
# 1635          NaN         2019            False    Riverside        33  False
#
# ...
